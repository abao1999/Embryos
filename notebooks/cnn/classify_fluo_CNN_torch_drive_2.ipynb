# %% [markdown]
# # CNN for Fluo Classification

# %% [markdown]
# This tutorial was very helpful, and some code here is taken from it: https://colab.research.google.com/drive/1B5KQvPySqYEa6XicRHdOwgv8fN1BrCgQ#scrollTo=LI6JtYwTt2HM

# %% [markdown]
# This code makes sure the shared drive mount (later on) will work:

# %%
# # https://github.com/googlecolab/colabtools/issues/1494
# !sed -i -e 's/enforce_single_parent:true/enforce_single_parent:true,metadata_cache_reset_counter:4/' /usr/local/lib/python3.6/dist-packages/google/colab/drive.py
# from google.colab import files, drive
# import importlib
# _ = importlib.reload(drive)

# %%
# https://stackoverflow.com/questions/48905127/importing-py-files-in-google-colab/48919022
import os
from google.colab import files, drive
src = list(files.upload().values())[0]
open('utils.py','wb').write(src)
# print(os.path.abspath('utils.py'))
import utils
help(utils)
# Out:
#      <input type="file" id="files-e9008b27-84b5-406b-b835-caa440329567" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e9008b27-84b5-406b-b835-caa440329567">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving utils.py to utils (5).py
# Help on module utils:
#
# NAME
#     utils
#
# FUNCTIONS
#     avg_across_z(img, normalize=False)
#         Returns a new image where each pixel
#         intensity is the average for that pixel across
#         all images in the z-stack.
#
#     get_img_at_t(t, img)
#
#     get_max_pixel(embryos, data_path)
#         Obtains the maximum pixel value across a set of embryos
#         embryos: subset of p_embryo... train, val, test
#         data_path: path from which to load processed np embryo data
#
#     get_z_slice(z, img)
#
#     max_across_z(img, normalize=False)
#         Returns a new image where each pixel
#         intensity is the maximum for that pixel across
#         all images in the z-stack.
#
#     middle_z(img)
#
#     min_across_z(img, normalize=False)
#         Returns a new image where each pixel
#         intensity is the minimum for that pixel across
#         all images in the z-stack.
#
#     normalize(img)
#         Normalizes pixel values across all images in img
#         to range 0-1.
#
#     save_nps_as_png(embryos, save_path, specs, window=None, normalize='per_embryo', dim=2, pol_subdir=True)
#         Save dataset in image format, sorted by polarization state
#         embryos: subset of p_embryo... train, val, test
#         specs = (data_path, pol_path, video_time_info)
#         save_path: path to save png to... data_path + {'train', 'val', 'test'}
#         specs: tuple with data_path (str: processed np embryo data),
#                           pol_path (str: embryo polarization labels),
#                           video_time_info (df: info per embryo)
#         window: number of t steps from first polarized index to ignore
#         normalize: type of normalization to apply (per_embryo, per_timestep, #)
#         dim: 2 or 3 (using 2d representation of z-stack or 3d selection of slices)
#         pol_subdir: whether to save images to "{save_path}/{pol}/" or "{save_path}/"
#
#     save_nps_subset_z(embryos, save_path, specs, window=None, normalize='per_embryo', mode='middle', n_slices=3, pol_subdir=True)
#         Save dataset in image format, sorted by polarization state
#         embryos: subset of p_embryo... train, val, test
#         specs = (data_path, pol_path, video_time_info)
#         save_path: path to save png to... data_path + {'train', 'val', 'test'}
#         specs: tuple with data_path (str: processed np embryo data),
#                           pol_path (str: embryo polarization labels),
#                           video_time_info (df: info per embryo)
#         window: number of t steps from first polarized index to ignore
#         normalize: type of normalization to apply (per_embryo, per_timestep, #)
#         mode: min, middle, max... where to start z slices (if middle, get z slices around middle)
#         n_slices: number of z slices to get
#         pol_subdir: whether to save images to "{save_path}/{pol}/" or "{save_path}/"
#
#     split_train_test_val(home_path, embryo_inds)
#         Splits a set of embryos into train/test/val:
#         home_path: path to shared drive folder
#         embryo_inds: list of embryos indices to use
#
#     within_window(embryo_idx, t, window, video_time_info)
#         Returns if an embryo timestep is close to the 1st polarized time
#         embryo_idx: index of current embryo (value from 'embryo_index' col)
#         t: timestep of current
#         window: number of t steps from first polarized index to ignore
#         video_time_info: dataframe with labeling/timing information per embryo
#
# DATA
#     CLEAN_IDX = [3, 12, 13, 16, 18, 19, 23, 24, 25, 33, 39, 42, 46, 47, 76...
#     CLEAN_IDX_FULL = [3, 12, 13, 16, 18, 19, 23, 24, 25, 33, 39, 42, 46, 4...
#     FULL_IDX = [1, 3, 12, 13, 16, 18, 19, 24, 39, 40, 42, 45, 46, 47, 49, ...
#     PARTIAL_IDX = [1, 3, 12, 13, 16, 18, 19, 24, 39, 40, 42, 45, 46, 47, 4...
#
# FILE
#     /content/utils.py

# %% [markdown]
# Install Conda

# %%
# !which python
# !python --version
# !echo $PYTHONPATH
# Out:
# /usr/local/bin/python
# Python 3.6.9
# /env/python

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR

print("Pytorch version: ", torch.__version__)
# Out:
# Pytorch version:  1.7.0+cu101

# %%
import pandas as pd
import numpy as np
import os, time, shutil
import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

# %% [markdown]
# ### Mount Google Drive

# %%
# drive.flush_and_unmount()
# mount the google drive to my Colab session
drive.mount('/content/gdrive')
# use the google drive in my Colab session
# home_path = '/content/gdrive/My Drive/cs101'
home_path = '/content/gdrive/Shared drives/Embryo_data'
print(os.listdir(home_path))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ['mxnet_cnn2d_embryo_58_fine_tune_data_aug_ResNet50_v2_order_random.ipynb', 'Embryo3', 'Embryo12', 'Embryo13', 'Embryo16', 'Embryo19', 'Embryo18', 'Embryo24', 'Embryo39', 'Embryo42', 'Embryo46', 'Embryo47', 'Embryo23', 'Embryo33', 'Embryo25', 'Embryo95', 'Embryo97', 'Embryo96', 'Embryo98', 'Embryo101', 'Embryo99', 'Embryo100', 'Embryo102', 'Embryo76', 'Embryo78', 'Embryo81', 'Embryo79', 'Embryo80', 'Embryo84', 'Embryo85', 'Embryo87', 'Embryo88', 'Embryo92', 'Embryo94', 'Embryo93', 'embryo_info_CS101.xlsx', 'data', 'processed', 'models', 'pix2pix_PyTorch-GAN.ipynb', 'annotation.xlsx', 'Embryo110', 'Embryo109', 'Embryo111', 'Embryo113', 'Embryo112', 'Embryo114', 'Embryo116', 'Embryo115', 'Embryo117', 'Embryo118', 'Embryo119', 'Embryo120', 'Embryo103', 'Embryo104', 'Embryo105', 'Embryo107', 'Embryo106', 'Embryo108', 'pix2pix_output', 'images']

# %% [markdown]
# ### Get Data

# %%
# Fixing the random seed for reproducibility
torch.manual_seed(42)
np.random.seed(42)

# Available high quality data
embryo_inds = utils.CLEAN_IDX

# Directory of the processed *.npy files
processed_path = f'{home_path}/processed'
polar_processed_path = f'{processed_path}/polarization'

video_time_info, train_embryos, val_embryos, test_embryos = utils.split_train_test_val(home_path, embryo_inds)

z_agg_mode = 'Max Z'
data_type = 'fluo_data'
data_path = f'{processed_path}/{data_type}/max'
pol_path = f'{processed_path}/polarization'
train_path = os.path.join(data_path, 'train')
val_path = os.path.join(data_path, 'val')
test_path = os.path.join(data_path, 'test')
# Out:
#               t_num  first_anno_pol_time
# embryo_index
# 3                21                   12
# 12              143                   11
# 13              143                   12
# 16              143                   30
# 18              143                   27
# 19              143                   32
# 23               40                   18
# 24               21                   20
# 25               21                   13
# 33               21                   15
# 39               21                   12
# 42               21                   16
# 46               21                   19
# 47               21                   17
# 76              109                   68
# 78              109                   75
# 79              109                   68
# 80              109                   65
# 81              109                   95
# 85              109                  102
# 87              109                   62
# 88              109                   75
# 92              109                   93
# 93              109                  100
# 94              109                   82
# 95              109                   85
# 96              109                  101
# 97              109                  109
# 98              109                   95
# 99              109                   69
# 100             109                   74
# 101             109                   84
# 102             109                   95
# [101, 78, 96, 80, 25, 33, 85, 88, 46, 3, 18, 79, 19, 47, 42, 94, 12, 13, 99, 16, 97, 93]
# [100, 92, 81]
# [95, 23, 87, 102, 24, 39, 76, 98]

# %% [markdown]
# ### Save NP Data as PNG for Training

# %%
if not os.path.exists(train_path):
    save_nps_as_png(train_embryos, train_path, window=None, normalize='per_embryo')
if not os.path.exists(val_path):
    save_nps_as_png(val_embryos, val_path, window=None, normalize='per_embryo')
if not os.path.exists(test_path):
    save_nps_as_png(test_embryos, test_path, window=None, normalize='per_embryo')

# %% [markdown]
# ### Set Hyperparameters

# %%
n_classes = 2

n_epochs = 50
learning_rate = 1e-3
momentum = 0.9
wd = 0.0001

per_device_batch_size = 20

lr_factor = 0.75
lr_steps = [10, 20, 30, np.inf]

num_workers = 1
num_gpus = 1
gpus = [i for i in range(num_gpus)]

device = torch.device(gpus[0]) if num_gpus > 0 else [torch.device('cpu')]

batch_size = per_device_batch_size * max(num_gpus, 1)

train_batch_size = batch_size
val_batch_size = batch_size * 2
test_batch_size = batch_size * 2
print(device)
# Out:
# cuda:0

# %% [markdown]
# Things to keep in mind:
#
# 1. ``epochs = 5`` is just for this tutorial with the tiny dataset. please change it to a larger number in your experiments, for instance 40.
# 2. ``per_device_batch_size`` is also set to a small number. In your experiments you can try larger number like 64.
# 3. remember to tune ``num_gpus`` and ``num_workers`` according to your machine.
# 4. A pre-trained model is already in a pretty good status. So we can start with a small ``lr``.
#
# ### Data Augmentation
#
# In transfer learning, data augmentation can also help.
# We use the following augmentation in training:
#
# 2. Randomly crop the image and resize it to 224x224
# 3. Randomly flip the image horizontally
# 4. Randomly jitter color and add noise
# 5. Transpose the data from height*width*num_channels to num_channels*height*width, and map values from [0, 255] to [0, 1]
# 6. Normalize with the mean and standard deviation from the ImageNet dataset.

# %%
transform = transforms.Compose([
    transforms.Resize(600),
    transforms.CenterCrop(512),

    transforms.RandomHorizontalFlip(), # Randomly flip the image horizontally
    transforms.RandomVerticalFlip(),
    # transforms.RandomLighting(0.1), # Add AlexNet-style PCA-based noise to an image... need to implement: https://github.com/facebook/fb.resnet.torch/blob/master/datasets/transforms.lua#L183
    # transforms.functional.adjust_contrast(contrast_factor=0.9 + np.random.random_sample()*0.2),
    transforms.ColorJitter(brightness=0.1, contrast=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %% [markdown]
# ### Data Loaders

# %% [markdown]
# With the data augmentation functions, we can define our data loaders:

# %%
def check_image(path):
    try:
        im = Image.open(path)
        return True
    except:
        return False

# for some reason, problem with file embryo_18_51.png in fluo_data/middle shows up sometimes during training, so maybe the check_image function is important
train_data = torchvision.datasets.ImageFolder(root=train_path, transform=transform, target_transform=None, is_valid_file=None)
val_data = torchvision.datasets.ImageFolder(root=val_path, transform=transform, target_transform=None, is_valid_file=None)
test_data = torchvision.datasets.ImageFolder(root=test_path, transform=transform, target_transform=None, is_valid_file=None)

print("Train data: ", train_data)
print("Validation data: ", val_data)
print("Test data: ", test_data)

def get_train_loader(batch_size):
    return torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, sampler=None, num_workers=num_workers)

def get_val_loader(batch_size):
    return torch.utils.data.DataLoader(val_data, batch_size=batch_size, shuffle=True, sampler=None, num_workers=num_workers)

def get_test_loader(batch_size):
  # drop last to avoid jagged array when evaluating predictions for accuracy
  return torch.utils.data.DataLoader(test_data, batch_size=batch_size, shuffle=True, sampler=None, num_workers=num_workers, drop_last=True)

# Define data loaders
# train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, shuffle=True, sampler=None, pin_memory=False, drop_last=False)
train_loader = get_train_loader(train_batch_size)
val_loader = get_val_loader(val_batch_size)
test_loader = get_test_loader(test_batch_size)

classes = ('unpolarized', 'polarized')
# Out:
# Train data:  Dataset ImageFolder
#     Number of datapoints: 2785
#     Root location: /content/gdrive/Shared drives/Embryo_data/processed/fluo_data/max/train
#     StandardTransform
# Transform: Compose(
#                Resize(size=600, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(512, 512))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ColorJitter(brightness=[0.9, 1.1], contrast=[0.9, 1.1], saturation=None, hue=None)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Validation data:  Dataset ImageFolder
#     Number of datapoints: 818
#     Root location: /content/gdrive/Shared drives/Embryo_data/processed/fluo_data/max/val
#     StandardTransform
# Transform: Compose(
#                Resize(size=600, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(512, 512))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ColorJitter(brightness=[0.9, 1.1], contrast=[0.9, 1.1], saturation=None, hue=None)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )
# Test data:  Dataset ImageFolder
#     Number of datapoints: 1289
#     Root location: /content/gdrive/Shared drives/Embryo_data/processed/fluo_data/max/test
#     StandardTransform
# Transform: Compose(
#                Resize(size=600, interpolation=PIL.Image.BILINEAR)
#                CenterCrop(size=(512, 512))
#                RandomHorizontalFlip(p=0.5)
#                RandomVerticalFlip(p=0.5)
#                ColorJitter(brightness=[0.9, 1.1], contrast=[0.9, 1.1], saturation=None, hue=None)
#                ToTensor()
#                Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#            )

# %% [markdown]
# Visualize some training images

# %%
# get some random training images
dataiter = iter(train_loader)
# next(dataiter)

images, labels = dataiter.next()

# show images

# functions to show an image
def imshow(img):
    """
    :param img: (PyTorch Tensor)
    """
    # unnormalize
    img = img / 2 + 0.5     
    # Convert tensor to numpy array
    npimg = img.numpy()
    plt.figure(figsize = (20,8))
    # Color channel first -> color channel last
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

  
imshow(torchvision.utils.make_grid(images))
# print labels
print(' '.join('{:>10}'.format(classes[labels[j]]) for j in range(batch_size)))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# unpolarized  polarized  polarized unpolarized  polarized unpolarized  polarized  polarized unpolarized  polarized  polarized unpolarized unpolarized unpolarized unpolarized  polarized unpolarized unpolarized unpolarized unpolarized

# %%
images[0].shape
# Out:
# torch.Size([3, 512, 512])

# %% [markdown]
# Note that only ``train_data`` uses ``transform_train``, while
# ``val_data`` and ``test_data`` use ``transform_test`` to produce deterministic
# results for evaluation.

# %% [markdown]
# ### Define Model
#
# Simple CNN for now

# %%
class SimpleConvolutionalNetwork(nn.Module):
    def __init__(self):
        super(SimpleConvolutionalNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(3, 20, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv2 = nn.Conv2d(20, 50, kernel_size=3, stride=1, padding=1)
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        self.conv3 = nn.Conv2d(50, 100, kernel_size=3, stride=1, padding=1)
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        # self.conv4 = nn.Conv2d(256, 512, kernel_size=3, stride=1, padding=1)
        # self.pool4 = nn.MaxPool2d(kernel_size=2, stride=2, padding=0)
        # # self.dropout = nn.Dropout(p=0.2)
        # self.batchnorm1 = nn.BatchNorm2d(20)
        # self.batchnorm2 = nn.BatchNorm2d(50)
        
        # cf comments in forward() to have step by step comments on shape progression
        # self.fc1 = nn.Linear(256 * 64 * 64, 64)
        self.fc1 = nn.Linear(100 * 64 * 64, 64)
        self.fc2 = nn.Linear(64, 2)

    def forward(self, x):
        """
        Forward pass,
        x shape is (batch_size, 3, 512, 512)
        (color channel first)
        in the comments, we omit the batch_size in the shape
        """
        # print(x.shape)

        # shape : 3x512x512 -> 20x512x512
        x = F.dropout(F.relu(self.conv1(x)), p=0.2, training=True)
        # x = self.batchnorm1(F.relu(self.conv1(x)))

        # x = F.relu(self.conv1(x))
        # print(x.shape)

        # 20x512x512 -> 20x256x256
        x = self.pool1(x)
        # print(x.shape)

        # 20x256x256 -> 50x256x256
        x = F.dropout(F.relu(self.conv2(x)), p=0.2, training=True)
        # x = self.batchnorm2(F.relu(self.conv2(x)))
        # x = F.relu(self.conv2(x))
        # print(x.shape)

        # 50x256x256 -> 50x128x128
        x = self.pool2(x)
        # print(x.shape)

        # 50x128x128 -> 100x128x128
        x = F.dropout(F.relu(self.conv3(x)), p=0.2, training=True)
        # print(x.shape)

        # 100x128x128 -> 100x64x64
        x = self.pool3(x)
        # print(x.shape)

        # 100x64x64 -> .
        x = x.view(-1, 100 * 64 *64)
        # print(x.shape)

        # . -> 64
        x = F.relu(self.fc1(x))
        # print(x.shape)

        # 64 -> 2
        # The softmax non-linearity is applied later (cf createLossAndOptimizer() fn)
        x = self.fc2(x)
        # print(x.shape)

        return x

# %% [markdown]
# ### Initialize Optimizer, Loss Criterion, and Scheduler

# %%
def createLossAndOptimizerAndScheduler(net, learning_rate=0.001, step=5, gamma=0.1):
    '''
    step: number of epochs after which to multiply learning rate by gamma
    gamma: multiplicated factor for learning rate decay
    '''
    # it combines softmax with negative log likelihood loss
    criterion = nn.CrossEntropyLoss()  
    #optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9)
    optimizer = optim.Adam(net.parameters(), lr=learning_rate)
    scheduler = StepLR(optimizer, step_size=step, gamma=gamma)
    return criterion, optimizer, scheduler

# %% [markdown]
# ###Save Model (re-implement later)

# %%
# Path to save trained models to, create folder
# model_name = 'basicCNN'
# embryo_type = 'fluo'
# model_save_path = os.path.join(home_path, 'models_cnn', f'{model_name}-{embryo_type}-batch{per_device_batch_size}-lr{lr}-step{step}-gamma{gamma}')
# if not os.path.isdir(model_save_path):
#   os.mkdir(model_save_path)
# else:
#   print(model_save_path, 'already exists')

# %% [markdown]
# ### Training Loop
#
# Following is the main training loop. It is the same as the loop in
# `CIFAR10 <dive_deep_cifar10.html>`__
# and ImageNet.

# %%
def train(net, batch_size, n_epochs, learning_rate):
    """
    Train a neural network and print statistics of the training
    
    :param net: (PyTorch Neural Network)
    :param batch_size: (int)
    :param n_epochs: (int)  Number of iterations on the training set
    :param learning_rate: (float) learning rate used by the optimizer
    """
    print("===== HYPERPARAMETERS =====")
    print("batch_size=", batch_size)
    print("n_epochs=", n_epochs)
    print("learning_rate=", learning_rate)
    print("=" * 30)
    
    train_loader = get_train_loader(batch_size)
    n_minibatches = len(train_loader)
    print("number of minibaches: ", n_minibatches)

    criterion, optimizer, scheduler = createLossAndOptimizerAndScheduler(net, learning_rate)
    # Init variables used for plotting the loss
    train_history = []
    val_history = []
    train_history_acc = []
    val_history_acc = []

    training_start_time = time.time()
    best_error = np.inf
    best_model_path = "best_model.pth"

    # mutli-gpu
    if gpus is not None and len(gpus) > 1:
        print('multi-gpu ', gpus)
        net = torch.nn.DataParallel(net, device_ids=gpus)  # model becomes `torch.nn.DataParallel` w/ model.module being the orignal `torch.nn.Module`
        net = net.to(device)

    # Move model to gpu if possible
    else:
        net = net.to(device)

    for epoch in range(n_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        print_every = n_minibatches // 10
        start_time = time.time()
        total_train_loss = 0
        n_correct_train = 0
        n_tot_points_train = 0
        
        for i, (inputs, labels) in enumerate(train_loader):

            # Move tensors to correct device
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)

            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # print statistics
            running_loss += loss.item()
            total_train_loss += loss.item()

            # print every 10th of epoch
            if (i + 1) % (print_every + 1) == 0:    
                print("Epoch {}, {:d}% \t train_loss: {:.2f} took: {:.2f}s".format(
                      epoch + 1, int(100 * (i + 1) / n_minibatches), running_loss / print_every,
                      time.time() - start_time))
                running_loss = 0.0
                start_time = time.time()

            _, predictions = torch.max(outputs.data, 1)
            n_correct_train += (predictions == labels).float().sum()
            n_tot_points_train += len(labels)

        
        train_accuracy = n_correct_train / n_tot_points_train
        train_history_acc.append(train_accuracy)
        train_history.append(total_train_loss / len(train_loader))

        total_val_loss = 0
        n_correct_val = 0
        n_tot_points_val = 0
        # Do a pass on the validation set
        # We don't need to compute gradient,
        # we save memory and computation using torch.no_grad()
        with torch.no_grad():
          for inputs, labels in val_loader:
              # Move tensors to correct device
              inputs, labels = inputs.to(device), labels.to(device)
              # Forward pass
              outputs = net(inputs)

              val_loss = criterion(outputs, labels)
              total_val_loss += val_loss.item()

              _, predictions = torch.max(outputs.data, 1)
              n_correct_val += (predictions == labels).float().sum()
              n_tot_points_val += len(labels)

        val_accuracy = n_correct_val / n_tot_points_val
        val_history_acc.append(val_accuracy)    
        val_history.append(total_val_loss / len(val_loader))
        # Save model that performs best on validation set
        if total_val_loss < best_error:
            best_error = total_val_loss
            torch.save(net.state_dict(), best_model_path)

        print("Validation loss = {:.2f}".format(total_val_loss / len(val_loader)))

    print("Training Finished, took {:.2f}s".format(time.time() - training_start_time))
    
    # Load best model
    net.load_state_dict(torch.load(best_model_path))
    
    return train_history, val_history, train_history_acc, val_history_acc

# %%
net = SimpleConvolutionalNetwork()

train_history, val_history, train_history_acc, val_history_acc = train(net, batch_size=batch_size, n_epochs=n_epochs, learning_rate=learning_rate)
# Out:
# ===== HYPERPARAMETERS =====
# batch_size= 20
# n_epochs= 50
# learning_rate= 0.001
# ==============================
# number of minibaches:  140
# Epoch 1, 10% 	 train_loss: 2.95 took: 8.03s
# Epoch 1, 21% 	 train_loss: 0.74 took: 7.81s
# Epoch 1, 32% 	 train_loss: 0.70 took: 7.72s
# Epoch 1, 42% 	 train_loss: 0.74 took: 7.69s
# Epoch 1, 53% 	 train_loss: 0.74 took: 7.70s
# Epoch 1, 64% 	 train_loss: 0.70 took: 7.80s
# Epoch 1, 75% 	 train_loss: 0.63 took: 7.91s
# Epoch 1, 85% 	 train_loss: 0.75 took: 7.63s
# Epoch 1, 96% 	 train_loss: 0.71 took: 7.87s
# Validation loss = 0.71
# Epoch 2, 10% 	 train_loss: 0.69 took: 8.31s
# Epoch 2, 21% 	 train_loss: 0.66 took: 8.01s
# Epoch 2, 32% 	 train_loss: 0.63 took: 7.97s
# Epoch 2, 42% 	 train_loss: 0.64 took: 7.82s
# Epoch 2, 53% 	 train_loss: 0.58 took: 7.92s
# Epoch 2, 64% 	 train_loss: 0.53 took: 7.85s
# Epoch 2, 75% 	 train_loss: 0.51 took: 7.87s
# Epoch 2, 85% 	 train_loss: 0.43 took: 7.79s
# Epoch 2, 96% 	 train_loss: 0.41 took: 7.86s
# Validation loss = 1.04
# Epoch 3, 10% 	 train_loss: 0.40 took: 7.95s
# Epoch 3, 21% 	 train_loss: 0.44 took: 7.71s
# Epoch 3, 32% 	 train_loss: 0.44 took: 7.73s
# Epoch 3, 42% 	 train_loss: 0.37 took: 7.67s
# Epoch 3, 53% 	 train_loss: 0.48 took: 7.61s
# Epoch 3, 64% 	 train_loss: 0.41 took: 7.55s
# Epoch 3, 75% 	 train_loss: 0.49 took: 7.57s
# Epoch 3, 85% 	 train_loss: 0.38 took: 7.56s
# Epoch 3, 96% 	 train_loss: 0.41 took: 7.49s
# Validation loss = 0.85
# Epoch 4, 10% 	 train_loss: 0.35 took: 7.73s
# Epoch 4, 21% 	 train_loss: 0.30 took: 7.60s
# Epoch 4, 32% 	 train_loss: 0.33 took: 7.61s
# Epoch 4, 42% 	 train_loss: 0.34 took: 7.54s
# Epoch 4, 53% 	 train_loss: 0.35 took: 7.54s
# Epoch 4, 64% 	 train_loss: 0.30 took: 7.41s
# Epoch 4, 75% 	 train_loss: 0.34 took: 7.48s
# Epoch 4, 85% 	 train_loss: 0.32 took: 7.45s
# Epoch 4, 96% 	 train_loss: 0.33 took: 7.40s
# Validation loss = 1.15
# Epoch 5, 10% 	 train_loss: 0.36 took: 7.71s
# Epoch 5, 21% 	 train_loss: 0.37 took: 7.51s
# Epoch 5, 32% 	 train_loss: 0.30 took: 7.44s
# Epoch 5, 42% 	 train_loss: 0.24 took: 7.50s
# Epoch 5, 53% 	 train_loss: 0.29 took: 7.40s
# Epoch 5, 64% 	 train_loss: 0.39 took: 7.41s
# Epoch 5, 75% 	 train_loss: 0.35 took: 7.37s
# Epoch 5, 85% 	 train_loss: 0.39 took: 7.44s
# Epoch 5, 96% 	 train_loss: 0.31 took: 7.37s
# Validation loss = 1.07
# Epoch 6, 10% 	 train_loss: 0.24 took: 7.60s
# Epoch 6, 21% 	 train_loss: 0.35 took: 7.37s
# Epoch 6, 32% 	 train_loss: 0.40 took: 7.37s
# Epoch 6, 42% 	 train_loss: 0.33 took: 7.34s
# Epoch 6, 53% 	 train_loss: 0.26 took: 7.41s
# Epoch 6, 64% 	 train_loss: 0.20 took: 7.33s
# Epoch 6, 75% 	 train_loss: 0.26 took: 7.40s
# Epoch 6, 85% 	 train_loss: 0.25 took: 7.39s
# Epoch 6, 96% 	 train_loss: 0.22 took: 7.51s
# Validation loss = 1.03
# Epoch 7, 10% 	 train_loss: 0.27 took: 7.52s
# Epoch 7, 21% 	 train_loss: 0.28 took: 7.28s
# Epoch 7, 32% 	 train_loss: 0.18 took: 7.30s
# Epoch 7, 42% 	 train_loss: 0.23 took: 7.27s
# Epoch 7, 53% 	 train_loss: 0.22 took: 7.30s
# Epoch 7, 64% 	 train_loss: 0.23 took: 7.37s
# Epoch 7, 75% 	 train_loss: 0.24 took: 7.35s
# Epoch 7, 85% 	 train_loss: 0.19 took: 7.43s
# Epoch 7, 96% 	 train_loss: 0.20 took: 7.50s
# Validation loss = 0.74
# Epoch 8, 10% 	 train_loss: 0.23 took: 7.64s
# Epoch 8, 21% 	 train_loss: 0.20 took: 7.43s
# Epoch 8, 32% 	 train_loss: 0.19 took: 7.43s
# Epoch 8, 42% 	 train_loss: 0.18 took: 7.35s
# Epoch 8, 53% 	 train_loss: 0.15 took: 7.48s
# Epoch 8, 64% 	 train_loss: 0.20 took: 7.56s
# Epoch 8, 75% 	 train_loss: 0.26 took: 7.39s
# Epoch 8, 85% 	 train_loss: 0.20 took: 7.52s
# Epoch 8, 96% 	 train_loss: 0.14 took: 7.51s
# Validation loss = 0.95
# Epoch 9, 10% 	 train_loss: 0.15 took: 7.54s
# Epoch 9, 21% 	 train_loss: 0.24 took: 7.42s
# Epoch 9, 32% 	 train_loss: 0.19 took: 7.53s
# Epoch 9, 42% 	 train_loss: 0.17 took: 7.49s
# Epoch 9, 53% 	 train_loss: 0.14 took: 7.47s
# Epoch 9, 64% 	 train_loss: 0.18 took: 7.33s
# Epoch 9, 75% 	 train_loss: 0.24 took: 7.45s
# Epoch 9, 85% 	 train_loss: 0.21 took: 7.43s
# Epoch 9, 96% 	 train_loss: 0.16 took: 7.32s
# Validation loss = 0.73
# Epoch 10, 10% 	 train_loss: 0.14 took: 7.59s
# Epoch 10, 21% 	 train_loss: 0.15 took: 7.35s
# Epoch 10, 32% 	 train_loss: 0.19 took: 7.34s
# Epoch 10, 42% 	 train_loss: 0.18 took: 7.57s
# Epoch 10, 53% 	 train_loss: 0.21 took: 7.44s
# Epoch 10, 64% 	 train_loss: 0.16 took: 7.42s
# Epoch 10, 75% 	 train_loss: 0.16 took: 7.45s
# Epoch 10, 85% 	 train_loss: 0.18 took: 7.36s
# Epoch 10, 96% 	 train_loss: 0.12 took: 7.37s
# Validation loss = 0.96
# Epoch 11, 10% 	 train_loss: 0.13 took: 7.55s
# Epoch 11, 21% 	 train_loss: 0.11 took: 7.36s
# Epoch 11, 32% 	 train_loss: 0.13 took: 7.34s
# Epoch 11, 42% 	 train_loss: 0.21 took: 7.38s
# Epoch 11, 53% 	 train_loss: 0.15 took: 7.41s
# Epoch 11, 64% 	 train_loss: 0.17 took: 7.41s
# Epoch 11, 75% 	 train_loss: 0.13 took: 7.30s
# Epoch 11, 85% 	 train_loss: 0.14 took: 7.32s
# Epoch 11, 96% 	 train_loss: 0.13 took: 7.33s
# Validation loss = 1.11
# Epoch 12, 10% 	 train_loss: 0.10 took: 7.71s
# Epoch 12, 21% 	 train_loss: 0.10 took: 7.44s
# Epoch 12, 32% 	 train_loss: 0.11 took: 7.33s
# Epoch 12, 42% 	 train_loss: 0.12 took: 7.45s
# Epoch 12, 53% 	 train_loss: 0.18 took: 7.38s
# Epoch 12, 64% 	 train_loss: 0.22 took: 7.34s
# Epoch 12, 75% 	 train_loss: 0.23 took: 7.30s
# Epoch 12, 85% 	 train_loss: 0.15 took: 7.32s
# Epoch 12, 96% 	 train_loss: 0.12 took: 7.31s
# Validation loss = 1.25
# Epoch 13, 10% 	 train_loss: 0.15 took: 7.45s
# Epoch 13, 21% 	 train_loss: 0.15 took: 7.28s
# Epoch 13, 32% 	 train_loss: 0.21 took: 7.34s
# Epoch 13, 42% 	 train_loss: 0.20 took: 7.39s
# Epoch 13, 53% 	 train_loss: 0.15 took: 7.26s
# Epoch 13, 64% 	 train_loss: 0.20 took: 7.27s
# Epoch 13, 75% 	 train_loss: 0.14 took: 7.35s
# Epoch 13, 85% 	 train_loss: 0.10 took: 7.26s
# Epoch 13, 96% 	 train_loss: 0.08 took: 7.26s
# Validation loss = 1.33
# Epoch 14, 10% 	 train_loss: 0.13 took: 7.51s
# Epoch 14, 21% 	 train_loss: 0.15 took: 7.29s
# Epoch 14, 32% 	 train_loss: 0.14 took: 7.35s
# Epoch 14, 42% 	 train_loss: 0.14 took: 7.28s
# Epoch 14, 53% 	 train_loss: 0.11 took: 7.23s
# Epoch 14, 64% 	 train_loss: 0.09 took: 7.23s
# Epoch 14, 75% 	 train_loss: 0.09 took: 7.28s
# Epoch 14, 85% 	 train_loss: 0.16 took: 7.28s
# Epoch 14, 96% 	 train_loss: 0.11 took: 7.29s
# Validation loss = 0.88
# Epoch 15, 10% 	 train_loss: 0.12 took: 7.59s
# Epoch 15, 21% 	 train_loss: 0.08 took: 7.39s
# Epoch 15, 32% 	 train_loss: 0.09 took: 7.29s
# Epoch 15, 42% 	 train_loss: 0.19 took: 7.25s
# Epoch 15, 53% 	 train_loss: 0.11 took: 7.29s
# Epoch 15, 64% 	 train_loss: 0.09 took: 7.35s
# Epoch 15, 75% 	 train_loss: 0.10 took: 7.43s
# Epoch 15, 85% 	 train_loss: 0.09 took: 7.33s
# Epoch 15, 96% 	 train_loss: 0.09 took: 7.28s
# Validation loss = 0.97
# Epoch 16, 10% 	 train_loss: 0.05 took: 7.80s
# Epoch 16, 21% 	 train_loss: 0.06 took: 7.31s
# Epoch 16, 32% 	 train_loss: 0.08 took: 7.24s
# Epoch 16, 42% 	 train_loss: 0.10 took: 7.30s
# Epoch 16, 53% 	 train_loss: 0.11 took: 7.26s
# Epoch 16, 64% 	 train_loss: 0.10 took: 7.26s
# Epoch 16, 75% 	 train_loss: 0.11 took: 7.42s
# Epoch 16, 85% 	 train_loss: 0.10 took: 7.54s
# Epoch 16, 96% 	 train_loss: 0.17 took: 7.53s
# Validation loss = 0.87
# Epoch 17, 10% 	 train_loss: 0.12 took: 7.76s
# Epoch 17, 21% 	 train_loss: 0.12 took: 7.58s
# Epoch 17, 32% 	 train_loss: 0.11 took: 7.53s
# Epoch 17, 42% 	 train_loss: 0.05 took: 7.48s
# Epoch 17, 53% 	 train_loss: 0.07 took: 7.57s
# Epoch 17, 64% 	 train_loss: 0.13 took: 7.54s
# Epoch 17, 75% 	 train_loss: 0.10 took: 7.62s
# Epoch 17, 85% 	 train_loss: 0.08 took: 7.61s
# Epoch 17, 96% 	 train_loss: 0.17 took: 7.58s
# Validation loss = 1.11
# Epoch 18, 10% 	 train_loss: 0.11 took: 7.58s
# Epoch 18, 21% 	 train_loss: 0.08 took: 7.59s
# Epoch 18, 32% 	 train_loss: 0.09 took: 7.60s
# Epoch 18, 42% 	 train_loss: 0.09 took: 7.56s
# Epoch 18, 53% 	 train_loss: 0.07 took: 7.58s
# Epoch 18, 64% 	 train_loss: 0.08 took: 7.52s
# Epoch 18, 75% 	 train_loss: 0.09 took: 7.60s
# Epoch 18, 85% 	 train_loss: 0.07 took: 7.67s
# Epoch 18, 96% 	 train_loss: 0.11 took: 7.65s
# Validation loss = 0.68
# Epoch 19, 10% 	 train_loss: 0.07 took: 8.15s
# Epoch 19, 21% 	 train_loss: 0.12 took: 7.64s
# Epoch 19, 32% 	 train_loss: 0.07 took: 7.66s
# Epoch 19, 42% 	 train_loss: 0.11 took: 7.55s
# Epoch 19, 53% 	 train_loss: 0.05 took: 7.66s
# Epoch 19, 64% 	 train_loss: 0.11 took: 7.73s
# Epoch 19, 75% 	 train_loss: 0.09 took: 7.67s
# Epoch 19, 85% 	 train_loss: 0.05 took: 7.79s
# Epoch 19, 96% 	 train_loss: 0.09 took: 7.65s
# Validation loss = 0.98
# Epoch 20, 10% 	 train_loss: 0.03 took: 7.61s
# Epoch 20, 21% 	 train_loss: 0.09 took: 7.40s
# Epoch 20, 32% 	 train_loss: 0.11 took: 7.41s
# Epoch 20, 42% 	 train_loss: 0.10 took: 7.41s
# Epoch 20, 53% 	 train_loss: 0.10 took: 7.35s
# Epoch 20, 64% 	 train_loss: 0.10 took: 7.35s
# Epoch 20, 75% 	 train_loss: 0.09 took: 7.39s
# Epoch 20, 85% 	 train_loss: 0.13 took: 7.34s
# Epoch 20, 96% 	 train_loss: 0.06 took: 7.30s
# Validation loss = 0.95
# Epoch 21, 10% 	 train_loss: 0.06 took: 7.53s
# Epoch 21, 21% 	 train_loss: 0.07 took: 7.27s
# Epoch 21, 32% 	 train_loss: 0.06 took: 7.29s
# Epoch 21, 42% 	 train_loss: 0.05 took: 7.33s
# Epoch 21, 53% 	 train_loss: 0.07 took: 7.35s
# Epoch 21, 64% 	 train_loss: 0.09 took: 7.43s
# Epoch 21, 75% 	 train_loss: 0.07 took: 7.61s
# Epoch 21, 85% 	 train_loss: 0.08 took: 7.46s
# Epoch 21, 96% 	 train_loss: 0.07 took: 7.30s
# Validation loss = 0.83
# Epoch 22, 10% 	 train_loss: 0.04 took: 7.54s
# Epoch 22, 21% 	 train_loss: 0.08 took: 7.28s
# Epoch 22, 32% 	 train_loss: 0.08 took: 7.27s
# Epoch 22, 42% 	 train_loss: 0.04 took: 7.57s
# Epoch 22, 53% 	 train_loss: 0.08 took: 7.97s
# Epoch 22, 64% 	 train_loss: 0.05 took: 7.84s
# Epoch 22, 75% 	 train_loss: 0.13 took: 7.67s
# Epoch 22, 85% 	 train_loss: 0.06 took: 7.50s
# Epoch 22, 96% 	 train_loss: 0.11 took: 7.48s
# Validation loss = 1.57
# Epoch 23, 10% 	 train_loss: 0.12 took: 7.79s
# Epoch 23, 21% 	 train_loss: 0.22 took: 7.57s
# Epoch 23, 32% 	 train_loss: 0.18 took: 7.54s
# Epoch 23, 42% 	 train_loss: 0.10 took: 7.69s
# Epoch 23, 53% 	 train_loss: 0.09 took: 7.52s
# Epoch 23, 64% 	 train_loss: 0.13 took: 7.53s
# Epoch 23, 75% 	 train_loss: 0.12 took: 7.58s
# Epoch 23, 85% 	 train_loss: 0.06 took: 7.56s
# Epoch 23, 96% 	 train_loss: 0.08 took: 7.58s
# Validation loss = 1.32
# Epoch 24, 10% 	 train_loss: 0.14 took: 7.82s
# Epoch 24, 21% 	 train_loss: 0.10 took: 7.69s
# Epoch 24, 32% 	 train_loss: 0.11 took: 7.58s
# Epoch 24, 42% 	 train_loss: 0.10 took: 7.54s
# Epoch 24, 53% 	 train_loss: 0.08 took: 7.60s
# Epoch 24, 64% 	 train_loss: 0.04 took: 7.69s
# Epoch 24, 75% 	 train_loss: 0.04 took: 7.54s
# Epoch 24, 85% 	 train_loss: 0.09 took: 7.62s
# Epoch 24, 96% 	 train_loss: 0.07 took: 7.57s
# Validation loss = 1.35
# Epoch 25, 10% 	 train_loss: 0.04 took: 8.09s
# Epoch 25, 21% 	 train_loss: 0.10 took: 7.60s
# Epoch 25, 32% 	 train_loss: 0.04 took: 7.52s
# Epoch 25, 42% 	 train_loss: 0.09 took: 7.60s
# Epoch 25, 53% 	 train_loss: 0.06 took: 7.59s
# Epoch 25, 64% 	 train_loss: 0.07 took: 7.69s
# Epoch 25, 75% 	 train_loss: 0.06 took: 7.66s
# Epoch 25, 85% 	 train_loss: 0.07 took: 7.71s
# Epoch 25, 96% 	 train_loss: 0.05 took: 7.72s
# Validation loss = 1.86
# Epoch 26, 10% 	 train_loss: 0.14 took: 7.97s
# Epoch 26, 21% 	 train_loss: 0.11 took: 7.66s
# Epoch 26, 32% 	 train_loss: 0.12 took: 7.68s
# Epoch 26, 42% 	 train_loss: 0.08 took: 7.67s
# Epoch 26, 53% 	 train_loss: 0.11 took: 7.67s
# Epoch 26, 64% 	 train_loss: 0.11 took: 7.57s
# Epoch 26, 75% 	 train_loss: 0.09 took: 7.78s
# Epoch 26, 85% 	 train_loss: 0.08 took: 7.81s
# Epoch 26, 96% 	 train_loss: 0.04 took: 7.81s
# Validation loss = 1.19
# Epoch 27, 10% 	 train_loss: 0.07 took: 7.89s
# Epoch 27, 21% 	 train_loss: 0.10 took: 7.72s
# Epoch 27, 32% 	 train_loss: 0.12 took: 7.69s
# Epoch 27, 42% 	 train_loss: 0.06 took: 7.80s
# Epoch 27, 53% 	 train_loss: 0.04 took: 7.82s
# Epoch 27, 64% 	 train_loss: 0.04 took: 7.76s
# Epoch 27, 75% 	 train_loss: 0.09 took: 7.67s
# Epoch 27, 85% 	 train_loss: 0.03 took: 7.90s
# Epoch 27, 96% 	 train_loss: 0.08 took: 7.72s
# Validation loss = 1.04
# Epoch 28, 10% 	 train_loss: 0.07 took: 7.90s
# Epoch 28, 21% 	 train_loss: 0.06 took: 7.75s
# Epoch 28, 32% 	 train_loss: 0.09 took: 7.83s
# Epoch 28, 42% 	 train_loss: 0.04 took: 7.80s
# Epoch 28, 53% 	 train_loss: 0.04 took: 7.72s
# Epoch 28, 64% 	 train_loss: 0.04 took: 7.77s
# Epoch 28, 75% 	 train_loss: 0.06 took: 7.84s
# Epoch 28, 85% 	 train_loss: 0.08 took: 7.76s
# Epoch 28, 96% 	 train_loss: 0.08 took: 7.85s
# Validation loss = 1.12
# Epoch 29, 10% 	 train_loss: 0.12 took: 7.96s
# Epoch 29, 21% 	 train_loss: 0.05 took: 7.78s
# Epoch 29, 32% 	 train_loss: 0.06 took: 7.86s
# Epoch 29, 42% 	 train_loss: 0.08 took: 8.04s
# Epoch 29, 53% 	 train_loss: 0.04 took: 8.10s
# Epoch 29, 64% 	 train_loss: 0.04 took: 7.85s
# Epoch 29, 75% 	 train_loss: 0.04 took: 7.82s
# Epoch 29, 85% 	 train_loss: 0.08 took: 7.85s
# Epoch 29, 96% 	 train_loss: 0.05 took: 7.96s
# Validation loss = 1.03
# Epoch 30, 10% 	 train_loss: 0.05 took: 8.20s
# Epoch 30, 21% 	 train_loss: 0.03 took: 7.99s
# Epoch 30, 32% 	 train_loss: 0.07 took: 7.92s
# Epoch 30, 42% 	 train_loss: 0.06 took: 7.96s
# Epoch 30, 53% 	 train_loss: 0.04 took: 7.79s
# Epoch 30, 64% 	 train_loss: 0.05 took: 7.88s
# Epoch 30, 75% 	 train_loss: 0.07 took: 7.90s
# Epoch 30, 85% 	 train_loss: 0.07 took: 7.89s
# Epoch 30, 96% 	 train_loss: 0.06 took: 7.81s
# Validation loss = 1.04
# Epoch 31, 10% 	 train_loss: 0.05 took: 8.19s
# Epoch 31, 21% 	 train_loss: 0.06 took: 8.01s
# Epoch 31, 32% 	 train_loss: 0.05 took: 7.83s
# Epoch 31, 42% 	 train_loss: 0.05 took: 8.02s
# Epoch 31, 53% 	 train_loss: 0.07 took: 7.95s
# Epoch 31, 64% 	 train_loss: 0.06 took: 7.94s
# Epoch 31, 75% 	 train_loss: 0.03 took: 7.96s
# Epoch 31, 85% 	 train_loss: 0.07 took: 7.92s
# Epoch 31, 96% 	 train_loss: 0.07 took: 7.85s
# Validation loss = 1.08
# Epoch 32, 10% 	 train_loss: 0.04 took: 8.19s
# Epoch 32, 21% 	 train_loss: 0.04 took: 7.96s
# Epoch 32, 32% 	 train_loss: 0.03 took: 7.91s
# Epoch 32, 42% 	 train_loss: 0.05 took: 7.86s
# Epoch 32, 53% 	 train_loss: 0.08 took: 8.07s
# Epoch 32, 64% 	 train_loss: 0.02 took: 7.87s
# Epoch 32, 75% 	 train_loss: 0.03 took: 8.06s
# Epoch 32, 85% 	 train_loss: 0.10 took: 8.14s
# Epoch 32, 96% 	 train_loss: 0.10 took: 8.02s
# Validation loss = 1.00
# Epoch 33, 10% 	 train_loss: 0.08 took: 8.20s
# Epoch 33, 21% 	 train_loss: 0.06 took: 7.91s
# Epoch 33, 32% 	 train_loss: 0.07 took: 7.89s
# Epoch 33, 42% 	 train_loss: 0.10 took: 7.91s
# Epoch 33, 53% 	 train_loss: 0.10 took: 8.00s
# Epoch 33, 64% 	 train_loss: 0.04 took: 7.99s
# Epoch 33, 75% 	 train_loss: 0.06 took: 7.94s
# Epoch 33, 85% 	 train_loss: 0.09 took: 8.06s
# Epoch 33, 96% 	 train_loss: 0.04 took: 7.99s
# Validation loss = 0.99
# Epoch 34, 10% 	 train_loss: 0.05 took: 8.18s
# Epoch 34, 21% 	 train_loss: 0.04 took: 7.88s
# Epoch 34, 32% 	 train_loss: 0.06 took: 7.90s
# Epoch 34, 42% 	 train_loss: 0.04 took: 7.97s
# Epoch 34, 53% 	 train_loss: 0.05 took: 7.86s
# Epoch 34, 64% 	 train_loss: 0.10 took: 8.03s
# Epoch 34, 75% 	 train_loss: 0.08 took: 8.03s
# Epoch 34, 85% 	 train_loss: 0.07 took: 7.99s
# Epoch 34, 96% 	 train_loss: 0.08 took: 7.95s
# Validation loss = 1.19
# Epoch 35, 10% 	 train_loss: 0.05 took: 8.22s
# Epoch 35, 21% 	 train_loss: 0.05 took: 7.98s
# Epoch 35, 32% 	 train_loss: 0.04 took: 8.05s
# Epoch 35, 42% 	 train_loss: 0.05 took: 8.10s
# Epoch 35, 53% 	 train_loss: 0.04 took: 8.07s
# Epoch 35, 64% 	 train_loss: 0.05 took: 8.10s
# Epoch 35, 75% 	 train_loss: 0.07 took: 8.10s
# Epoch 35, 85% 	 train_loss: 0.07 took: 8.08s
# Epoch 35, 96% 	 train_loss: 0.08 took: 8.03s
# Validation loss = 1.03
# Epoch 36, 10% 	 train_loss: 0.04 took: 8.19s
# Epoch 36, 21% 	 train_loss: 0.09 took: 7.96s
# Epoch 36, 32% 	 train_loss: 0.07 took: 8.14s
# Epoch 36, 42% 	 train_loss: 0.09 took: 8.06s
# Epoch 36, 53% 	 train_loss: 0.07 took: 8.03s
# Epoch 36, 64% 	 train_loss: 0.06 took: 8.09s
# Epoch 36, 75% 	 train_loss: 0.02 took: 8.08s
# Epoch 36, 85% 	 train_loss: 0.03 took: 8.09s
# Epoch 36, 96% 	 train_loss: 0.06 took: 8.02s
# Validation loss = 0.94
# Epoch 37, 10% 	 train_loss: 0.03 took: 8.38s
# Epoch 37, 21% 	 train_loss: 0.05 took: 8.19s
# Epoch 37, 32% 	 train_loss: 0.04 took: 8.16s
# Epoch 37, 42% 	 train_loss: 0.04 took: 8.10s
# Epoch 37, 53% 	 train_loss: 0.02 took: 8.05s
# Epoch 37, 64% 	 train_loss: 0.04 took: 8.01s
# Epoch 37, 75% 	 train_loss: 0.08 took: 8.14s
# Epoch 37, 85% 	 train_loss: 0.09 took: 8.09s
# Epoch 37, 96% 	 train_loss: 0.08 took: 8.12s
# Validation loss = 1.14
# Epoch 38, 10% 	 train_loss: 0.06 took: 8.27s
# Epoch 38, 21% 	 train_loss: 0.05 took: 8.01s
# Epoch 38, 32% 	 train_loss: 0.05 took: 8.14s
# Epoch 38, 42% 	 train_loss: 0.05 took: 8.12s
# Epoch 38, 53% 	 train_loss: 0.09 took: 8.14s
# Epoch 38, 64% 	 train_loss: 0.07 took: 8.16s
# Epoch 38, 75% 	 train_loss: 0.09 took: 8.16s
# Epoch 38, 85% 	 train_loss: 0.15 took: 8.16s
# Epoch 38, 96% 	 train_loss: 0.06 took: 8.22s
# Validation loss = 0.97
# Epoch 39, 10% 	 train_loss: 0.07 took: 8.51s
# Epoch 39, 21% 	 train_loss: 0.10 took: 8.23s
# Epoch 39, 32% 	 train_loss: 0.15 took: 8.12s
# Epoch 39, 42% 	 train_loss: 0.06 took: 8.14s
# Epoch 39, 53% 	 train_loss: 0.04 took: 8.12s
# Epoch 39, 64% 	 train_loss: 0.05 took: 8.15s
# Epoch 39, 75% 	 train_loss: 0.06 took: 8.27s
# Epoch 39, 85% 	 train_loss: 0.06 took: 8.17s
# Epoch 39, 96% 	 train_loss: 0.05 took: 8.17s
# Validation loss = 0.93
# Epoch 40, 10% 	 train_loss: 0.04 took: 8.35s
# Epoch 40, 21% 	 train_loss: 0.06 took: 8.13s
# Epoch 40, 32% 	 train_loss: 0.04 took: 8.26s
# Epoch 40, 42% 	 train_loss: 0.04 took: 8.23s
# Epoch 40, 53% 	 train_loss: 0.09 took: 8.14s
# Epoch 40, 64% 	 train_loss: 0.07 took: 8.14s
# Epoch 40, 75% 	 train_loss: 0.06 took: 8.17s
# Epoch 40, 85% 	 train_loss: 0.06 took: 8.20s
# Epoch 40, 96% 	 train_loss: 0.05 took: 8.14s
# Validation loss = 0.77
# Epoch 41, 10% 	 train_loss: 0.03 took: 8.39s
# Epoch 41, 21% 	 train_loss: 0.03 took: 8.26s
# Epoch 41, 32% 	 train_loss: 0.05 took: 8.19s
# Epoch 41, 42% 	 train_loss: 0.04 took: 8.15s
# Epoch 41, 53% 	 train_loss: 0.03 took: 8.12s
# Epoch 41, 64% 	 train_loss: 0.05 took: 8.21s
# Epoch 41, 75% 	 train_loss: 0.04 took: 8.20s
# Epoch 41, 85% 	 train_loss: 0.03 took: 8.10s
# Epoch 41, 96% 	 train_loss: 0.06 took: 8.12s
# Validation loss = 0.98
# Epoch 42, 10% 	 train_loss: 0.05 took: 8.43s
# Epoch 42, 21% 	 train_loss: 0.10 took: 8.24s
# Epoch 42, 32% 	 train_loss: 0.09 took: 8.35s
# Epoch 42, 42% 	 train_loss: 0.06 took: 8.32s
# Epoch 42, 53% 	 train_loss: 0.04 took: 8.16s
# Epoch 42, 64% 	 train_loss: 0.08 took: 8.18s
# Epoch 42, 75% 	 train_loss: 0.02 took: 8.13s
# Epoch 42, 85% 	 train_loss: 0.07 took: 8.25s
# Epoch 42, 96% 	 train_loss: 0.04 took: 8.16s
# Validation loss = 0.64
# Epoch 43, 10% 	 train_loss: 0.05 took: 8.42s
# Epoch 43, 21% 	 train_loss: 0.04 took: 8.11s
# Epoch 43, 32% 	 train_loss: 0.02 took: 8.07s
# Epoch 43, 42% 	 train_loss: 0.06 took: 8.18s
# Epoch 43, 53% 	 train_loss: 0.05 took: 8.18s
# Epoch 43, 64% 	 train_loss: 0.04 took: 8.25s
# Epoch 43, 75% 	 train_loss: 0.02 took: 8.24s
# Epoch 43, 85% 	 train_loss: 0.07 took: 8.20s
# Epoch 43, 96% 	 train_loss: 0.03 took: 8.17s
# Validation loss = 1.00
# Epoch 44, 10% 	 train_loss: 0.03 took: 8.26s
# Epoch 44, 21% 	 train_loss: 0.04 took: 8.19s
# Epoch 44, 32% 	 train_loss: 0.05 took: 8.14s
# Epoch 44, 42% 	 train_loss: 0.03 took: 8.09s
# Epoch 44, 53% 	 train_loss: 0.03 took: 8.11s
# Epoch 44, 64% 	 train_loss: 0.05 took: 8.21s
# Epoch 44, 75% 	 train_loss: 0.02 took: 8.15s
# Epoch 44, 85% 	 train_loss: 0.08 took: 8.16s
# Epoch 44, 96% 	 train_loss: 0.08 took: 8.10s
# Validation loss = 1.36
# Epoch 45, 10% 	 train_loss: 0.04 took: 8.45s
# Epoch 45, 21% 	 train_loss: 0.05 took: 8.25s
# Epoch 45, 32% 	 train_loss: 0.02 took: 8.22s
# Epoch 45, 42% 	 train_loss: 0.08 took: 8.25s
# Epoch 45, 53% 	 train_loss: 0.07 took: 8.21s
# Epoch 45, 64% 	 train_loss: 0.04 took: 8.48s
# Epoch 45, 75% 	 train_loss: 0.05 took: 8.20s
# Epoch 45, 85% 	 train_loss: 0.10 took: 8.20s
# Epoch 45, 96% 	 train_loss: 0.05 took: 8.20s
# Validation loss = 1.17
# Epoch 46, 10% 	 train_loss: 0.07 took: 8.38s
# Epoch 46, 21% 	 train_loss: 0.06 took: 8.31s
# Epoch 46, 32% 	 train_loss: 0.05 took: 8.18s
# Epoch 46, 42% 	 train_loss: 0.13 took: 8.27s
# Epoch 46, 53% 	 train_loss: 0.08 took: 8.25s
# Epoch 46, 64% 	 train_loss: 0.08 took: 8.23s
# Epoch 46, 75% 	 train_loss: 0.08 took: 8.17s
# Epoch 46, 85% 	 train_loss: 0.07 took: 8.23s
# Epoch 46, 96% 	 train_loss: 0.03 took: 8.14s
# Validation loss = 1.45
# Epoch 47, 10% 	 train_loss: 0.09 took: 8.36s
# Epoch 47, 21% 	 train_loss: 0.07 took: 8.12s
# Epoch 47, 32% 	 train_loss: 0.04 took: 8.14s
# Epoch 47, 42% 	 train_loss: 0.05 took: 8.20s
# Epoch 47, 53% 	 train_loss: 0.03 took: 8.09s
# Epoch 47, 64% 	 train_loss: 0.04 took: 8.20s
# Epoch 47, 75% 	 train_loss: 0.07 took: 8.17s
# Epoch 47, 85% 	 train_loss: 0.04 took: 8.20s
# Epoch 47, 96% 	 train_loss: 0.09 took: 8.16s
# Validation loss = 1.74
# Epoch 48, 10% 	 train_loss: 0.09 took: 8.36s
# Epoch 48, 21% 	 train_loss: 0.05 took: 8.31s
# Epoch 48, 32% 	 train_loss: 0.05 took: 8.16s
# Epoch 48, 42% 	 train_loss: 0.02 took: 8.17s
# Epoch 48, 53% 	 train_loss: 0.04 took: 8.15s
# Epoch 48, 64% 	 train_loss: 0.05 took: 8.13s
# Epoch 48, 75% 	 train_loss: 0.06 took: 8.21s
# Epoch 48, 85% 	 train_loss: 0.04 took: 8.31s
# Epoch 48, 96% 	 train_loss: 0.08 took: 8.17s
# Validation loss = 1.03
# Epoch 49, 10% 	 train_loss: 0.08 took: 8.37s
# Epoch 49, 21% 	 train_loss: 0.05 took: 8.15s
# Epoch 49, 32% 	 train_loss: 0.05 took: 8.15s
# Epoch 49, 42% 	 train_loss: 0.06 took: 8.10s
# Epoch 49, 53% 	 train_loss: 0.05 took: 8.22s
# Epoch 49, 64% 	 train_loss: 0.01 took: 8.25s
# Epoch 49, 75% 	 train_loss: 0.04 took: 8.25s
# Epoch 49, 85% 	 train_loss: 0.06 took: 8.17s
# Epoch 49, 96% 	 train_loss: 0.06 took: 8.11s
# Validation loss = 1.64
# Epoch 50, 10% 	 train_loss: 0.04 took: 8.43s
# Epoch 50, 21% 	 train_loss: 0.04 took: 8.16s
# Epoch 50, 32% 	 train_loss: 0.03 took: 8.18s
# Epoch 50, 42% 	 train_loss: 0.02 took: 8.10s
# Epoch 50, 53% 	 train_loss: 0.04 took: 8.12s
# Epoch 50, 64% 	 train_loss: 0.06 took: 8.13s
# Epoch 50, 75% 	 train_loss: 0.06 took: 8.08s
# Epoch 50, 85% 	 train_loss: 0.04 took: 8.11s
# Epoch 50, 96% 	 train_loss: 0.05 took: 8.26s
# Validation loss = 0.85
# Training Finished, took 4633.98s

# %%
def test(model, device, test_loader):
    criterion = nn.CrossEntropyLoss(reduction='sum')
    model.eval()    # Set the model to inference mode
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():   # For the inference step, gradient is not computed
        for data0 in test_loader:
            data = data0['img']
            target = data0['label']
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += criterion(output, target).item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += len(target)

    test_loss /= total

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, total,
        100. * correct / total))
    return test_loss, correct / total

# %% [markdown]
# ## Metrics and Visualization

# %% [markdown]
# Evaluate the accuracy

# %%
def dataset_accuracy(net, data_loader, name=""):
    net = net.to(device)
    correct = 0
    total = 0
    for images, labels in data_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
    accuracy = 100 * float(correct) / total
    print('Accuracy of the network on the {} {} images: {:.2f} %'.format(total, name, accuracy))

def train_set_accuracy(net):
    dataset_accuracy(net, train_loader, "train")

def val_set_accuracy(net):
    dataset_accuracy(net, val_loader, "validation")  
    
def test_set_accuracy(net):
    dataset_accuracy(net, test_loader, "test")

def compute_accuracy(net):
    train_set_accuracy(net)
    val_set_accuracy(net)
    test_set_accuracy(net)
    
print("Computing accuracy...")
compute_accuracy(net)
# Out:
# Computing accuracy...
# Accuracy of the network on the 2785 train images: 97.45 %
# Accuracy of the network on the 818 validation images: 87.65 %
# Accuracy of the network on the 1280 test images: 91.02 %

# %% [markdown]
# ### Plot results

# %%
def plot_losses(train_history, val_history):
    x = np.arange(1, len(train_history) + 1)

    plt.figure(figsize=(8, 6), dpi=100)
    plt.plot(x, train_history, '-r', label="Training loss", linewidth=2)
    plt.plot(x, val_history, '-b', label="Validation loss", linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend(loc='upper right')
    plt.title("Training and Validation Loss History")
    plt.show()

def plot_accuracy(train_accs, val_accs):
    x = np.arange(1, len(train_history) + 1)

    plt.figure(figsize=(8, 6), dpi=100)
    plt.plot(x, train_accs, '-r', label="Training accuracy", linewidth=2)
    plt.plot(x, val_accs, '-b', label="Validation accuracy", linewidth=2)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend(loc='upper right')
    plt.title("Training and Validation Accuracy History")
    plt.show()

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    from http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
    :param cm: (numpy matrix) confusion matrix
    :param classes: [str]
    :param normalize: (bool)
    :param title: (str)
    :param cmap: (matplotlib color map)
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        
    plt.figure(figsize=(8, 8), dpi=100)   
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
plot_accuracy(train_history_acc, val_history_acc)
plot_losses(train_history, val_history)

# %%
import itertools

test_batch_size = batch_size

def accuracy_per_class(net):
    net = net.to(device)
    n_classes = 2
    # (real, predicted)
    confusion_matrix = np.zeros((n_classes, n_classes), dtype=np.int64)

    for images, labels in test_loader:
        images, labels = images, labels = images.to(device), labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        for i in range(test_batch_size):
            confusion_matrix[labels[i], predicted[i]] += 1
            label = labels[i]

    print("{:<10} {:^10}".format("Class", "Accuracy (%)"))
    for i in range(n_classes):
        class_total = confusion_matrix[i, :].sum()
        class_correct = confusion_matrix[i, i]
        percentage_correct = 100.0 * float(class_correct) / class_total
        
        print('{:<10} {:^10.2f}'.format(classes[i], percentage_correct))
    return confusion_matrix

confusion_matrix = accuracy_per_class(net)
# Out:
# Class      Accuracy (%)
# unpolarized   93.21
# polarized    86.40

# %%
# Plot normalized confusion matrix
plot_confusion_matrix(confusion_matrix, classes, normalize=True,
                      title='Normalized confusion matrix')

# Plot non-normalized confusion matrix
plot_confusion_matrix(confusion_matrix, classes,
                      title='Confusion matrix, without normalization')

# %%
print(net)
# Out:
# SimpleConvolutionalNetwork(
#   (conv1): Conv2d(3, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(20, 50, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(50, 100, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool3): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=409600, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=2, bias=True)
# )

# %%
# !pip install torchsummary
# Out:
# Requirement already satisfied: torchsummary in /usr/local/lib/python3.6/dist-packages (1.5.1)

# %%
from torchsummary import summary
summary(net, (3,512,512))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 20, 512, 512]             560
#          MaxPool2d-2         [-1, 20, 256, 256]               0
#             Conv2d-3         [-1, 50, 256, 256]           9,050
#          MaxPool2d-4         [-1, 50, 128, 128]               0
#             Conv2d-5        [-1, 100, 128, 128]          45,100
#          MaxPool2d-6          [-1, 100, 64, 64]               0
#             Linear-7                   [-1, 64]      26,214,464
#             Linear-8                    [-1, 2]             130
# ================================================================
# Total params: 26,269,304
# Trainable params: 26,269,304
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.00
# Forward/backward pass size (MB): 96.88
# Params size (MB): 100.21
# Estimated Total Size (MB): 200.08
# ----------------------------------------------------------------

# %%
# # Save the best model to shared drive
import shutil
shutil.move("/content/best_model.pth", "/content/gdrive/Shared drives/Embryo_data/models/best/torchCNN-max-windowNone-windowNone-batch20-lr0.01-best-val-acc.pth")
# Out:
# '/content/gdrive/Shared drives/Embryo_data/models/best/torchCNN-max-windowNone-windowNone-batch20-lr0.01-best-val-acc.pth'
